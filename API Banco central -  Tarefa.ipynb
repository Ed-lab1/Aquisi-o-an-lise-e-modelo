# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
codigo = 433

# %%
def consulta_bc(codigo):
    url ='http://api.bcb.gov.br/dados/serie/bcdata.sgs.{}/dados?formato=json'.format(codigo)
    df = pd.read_json(url)
    df['data'] = pd.to_datetime(df['data'], dayfirst=True)
    df.set_index('data', inplace = True)
    return df

# %%
ipca =  consulta_bc(433)
ipca.plot()
# Out:
# <AxesSubplot:xlabel='data'>

# %%
igpm = consulta_bc(189)
igpm
# Out:
#             valor
# data
# 1989-06-01  19.68
# 1989-07-01  35.90
# 1989-08-01  36.92
# 1989-09-01  39.92
# 1989-10-01  40.64
# ...           ...
# 2020-10-01   3.23
# 2020-11-01   3.28
# 2020-12-01   0.96
# 2021-01-01   2.58
# 2021-02-01   2.53
#
# [381 rows x 1 columns]

# %%
selic_meta = consulta_bc(432)
selic_meta.plot()
# Out:
# <AxesSubplot:xlabel='data'>

# %%
reserva_int = consulta_bc(13621)
reserva_int.plot()
# Out:
# <AxesSubplot:xlabel='data'>

# %%
taxa_desocup = consulta_bc(24369)
taxa_desocup.plot()
# Out:
# <AxesSubplot:xlabel='data'>
